# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/rs/robosuite_dome/robosuite/models/assets/demonstrations/1692673745_720847/lift_dome.hdf5"

# %%
with h5py.File(path, "r") as f:
    i = 330
    imgs = f['data']['demo_1']['obs']['robot0_eye_in_hand_image']
    bimgs = f['data']['demo_1']['obs']['agentview_image']
    #show both first images
    plt.imshow(imgs[i])
    plt.show()
    plt.imshow(bimgs[i])
    plt.show()
